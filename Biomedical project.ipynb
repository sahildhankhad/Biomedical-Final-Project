# %% [markdown]
# #                                          Introduction of Python

# %% [markdown]
# ##### Sahil Dhankhad(0674692)

# %% [markdown]
# 1.$Introduction$
#
# 2.$Anaconda$
#
# 3.$Jupyter Notebook$
#
# 4.$First Program$
#
# 5.$Python Comments$
#
# 6.$Operator$
#
# 7.$Variable$
#
# 8.$List$
#
# 9.$Numpy Array$
#
# 10.$Function$
#
# 11.$Ploting$
#
# 12.$Reading the input$
#
# 13.$Reference$

# %% [markdown]
# # 1.Introduction

# %% [markdown]
# This notebook will introduce you to programming in Python, using the Jupyter Notebook environment.
#
# To begin, Python is what is known as an interpreted language. In other words, Python program executes your code by interpreting it and translating it to machine language to be executed. This type of language is typically closer to human language, making it easier to learn, but is slower to execute than compiled languages like C and Fortran. Compiled languages takes the code, compiles it into executeble machine code, which can then be run much faster. There are some technologies to improve Python speed (Just in Time compiler), but we will forgo that for now. Speed really isn't an issue yet, we need to first learn how to write the code.
#
# The power of Python comes from the large open source community of developerss that have done the heavy lifting for many tasks by creating well documented, easy to use libraries to help you write useful code quickly. There are particularly many libraries for data analytic functions, which is why Python is often the weapon of choice for data scientists, digital marketers, and data intensive businesses.
#
# This Tutorial shows how to:
# 1.Learn the basics of python
# 2.Learn to use the jupter python.

# %% [markdown]
# ## 2.Anaconda:-
#
# You will find the Anaconda distribution on https://www.anaconda.com/download/.
# After that you need to open the jupyter notebook to use it.

# %% [markdown]
# ### 3.Jupyter Notebook

# %% [markdown]
# If you want to install or update any  python package you can use the following process.
#
# If using Anaconda, update Jupyter using conda:
#
# !$conda$ $update$ $your package$      Don't forget to add ! in starting of your line. Because it will tell python you want to install or update something.
#
# If you are installing any new package
#
# !$conda$ $insatll$ $your package$

# %% [markdown]
# ![title](notebook.png)
#
# $1$.Notebook name which you can change by clicking on it and the file format is always is in $.ipnb$.
#
# $2$.The Menu bar give you some freedom to do things in python and do some changes with your program.
#
# $3$.To the right of your meanu, you have kernel. you can change your kernel language at your notebok from kernele bar.
#
# $4$.Toolbar gives you some freedom to do some prcesses very quickly like: running your code, adding new cell, removing any cell you want to remove it or saving any cell. Most importantly a droupdown menu, it gives you some features and important one change to writing or coding.

# %% [markdown]
# #### Markdown Cell

# %% [markdown]
# $1$.Markdown cell contains rich text. In addition to classic formatting options like bold or italics, we can add links, images, HTML elements, LaTeX mathematical equations, and more.
#
# $2$.A code cell contains code to be executed by the kernel. The programming language corresponds to the kernel’s language. We will only use Python in this book, but you can use many other languages.

# %% [markdown]
# ## 4 First Program:-

# %%
print('Helloo World')
# Out:
# Helloo World

# %%
print('we are stuyding in Lakehead Univeristy, Thunder bay Campus')
# Out:
# we are stuyding in Lakehead Univeristy, Thunder bay Campus

# %% [markdown]
# ## 5.Python Comments
#
# In python commenting is little bit different from the other languages. But it is easy to use here. Basically, in python there are two ways to comment,( single line),(mutiple line).
# Single line commenting is good for a short, quick comment , while the block comment is often used to describe something much more in detail or to block out an entire chunk of code.

# %% [markdown]
# ###### Single line comments:-
# Typically, you just use the # (pound) sign to comment out everything that follows it on that line.

# %%
#print('we are stuyding in lakehead university') Single line

# %% [markdown]
# ##### Mutiple line Comments:-
#    Multiple line comments are slightly different. Simply use 3 single quotes before and after the part you want commented.

# %%
'''

print("We are in a comment")

print ("We are still in a comment")

'''
# Out:
# '\n\nprint("We are in a comment")\n\nprint ("We are still in a comment")\n\n'

# %% [markdown]
# If you want to add some more senstences in one line you can use string.Please note string is very important command in Ipython. It helps you to print line or number in Ipython. I will show you some examples of using string. But you can use print(\n) giving a space between the upper line and lower line here.

# %%
string1= 'Hello'
string2='Thunder bay'
string3='Today, Temperature is -12 degree outside'
# now if you want to print all of this string together 
print(string1,string2)
print('\n') # this command give space between two lines here
print(string1,string2,string3)
# Out:
# ('Hello', 'Thunder bay')
#
#
# ('Hello', 'Thunder bay', 'Today, Temperature is -12 degree outside')

# %%
x = 10

# %%
x
# Out:
# 10

# %%
x, y = 5, 6  # we can just simply give assign value like this
x, y
# Out:
# (5, 6)

# %%
y, x=x, y  # we can interchange the value among the variable
x,y
# Out:
# (6, 5)

# %% [markdown]
# ## 6.Operator

# %% [markdown]
# Operators are the constructs which can manipulate the value of operands.
#
# Consider the expression 4 + 5 = 9. Here, 4 and 5 are called operands and + is called operator.
#
#
# $Types of Operator$
#
# Python language supports the following types of operators.
#
# 1.Arithmetic Operators
#
# 2.Comparison (Relational) Operators
#
# 3.Assignment Operators
#
# 4.Logical Operators
#
# 5.Bitwise Operators
#
# 6.Membership Operators
#
# 7.Identity Operators

# %% [markdown]
# ###### Addtion,subtraction,multiplation,division

# %%
# comments follow "#" sign
3+2 # we can do addition
# Out:
# 5

# %%
3-2 # we can do subtraction
# Out:
# 1

# %%
3*2 #multiplcation
# Out:
# 6

# %%
3/2 #division
# Out:
# 1

# %% [markdown]
# Reason we get this value 1 instead of 1.5!!
#
# This is a good time to introduce the concept of data types. 3 and 2 are both integers, so the default result of the division of 2 integers is to return another integer. In this case, it is the closest integer lower than the actual result. We can complete the operation as expected by changing one of the data types to "float." A float is a decimal.

# %%
3./2 # Look, now it worked! We can do division as expected because of the "." after the 3
# Out:
# 1.5

# %%
from __future__ import division # this means, from the __future__ module, import the function division
# using this module, in the end we don't need to use point
3/2
# Out:
# 1.5

# %%
5/6 # now all of our division works as expected, as long as the above cell has been executed
# Out:
# 0.8333333333333334

# %% [markdown]
# ### Loop

# %% [markdown]
# ##### for:-
#
# In our daily life under sertain situations, some time decisions are inevitable. Same condition is applied on the program also.In program conditional statements are performed by different actions.The condition usually uses comparisons and arithmetic expressions with variables.

# %%
for num in range(6):
    print(num)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# The for num in range syntax means that a temporary variable named $num$ is created at every iteration. This variable contains the value of every $num$ in the range, one at a time.

# %% [markdown]
# ###### while

# %%
num=0
while num < 7:
    print(num)
    num+=1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for number in ["4456", "2218", "2834", "8789"]:
    print(number)
# Out:
# 4456
# 2218
# 2834
# 8789

# %% [markdown]
# ## 7.Variable

# %% [markdown]
# Variable are very important for programming. It is specific ,case-sensitive name and call up value through variable name.

# %%
x=6 # here i assign the 5 to x, that means set variable as target value
y=10
a=x+7 # now assign a variable that sum of two variable
print(a) #print is a reserved keyword function in Python that outputs the subsequent code
# Out:
# 13

# %% [markdown]
# Now i'm going to make a whole program using all operators; So, you will understand more how to use the opeator using variable.

# %%
num1=15
num2=20
print("num1+num2=",num1+num2)
print("num1-num2=",num1-num2)
print("num1*num2=",num1*num2)
print("num1/num2=",num1/num2)
print("2^7",2**7)
print("20%3",20%3)
print("17//3",17//3)
# Out:
# ('num1+num2=', 35)
# ('num1-num2=', -5)
# ('num1*num2=', 300)
# ('num1/num2=', 0)
# ('2^7', 128)
# ('20%3', 2)
# ('17//3', 5)

# %%
height=1.79
weight=68.7
#now print height
print(height)
# Out:
# 1.79

# %% [markdown]
# Metric BMI Formula
#
# BMI = weight (kg) ÷ height2 (m2)
#
# Now we are going to calculate BMI;

# %%
BMI=68.7/1.79**2
BMI
# Out:
# 21.44127836209856

# %%
#or you can use your variable also
bmi=weight/height**2
bmi
# Out:
# 21.44127836209856

# %%
# or you can use print; to print your BMI output
print(bmi)
# Out:
# 21.4412783621

# %% [markdown]
# If we want to know the type of our variable we can use Type()

# %%
type(y)
type(a)
# Out:
# int

# %%
# lets check the type of bmi
type(bmi)
# Out:
# <type 'float'>

# %%
x+b #  this won't work because we haven't assigned anything to b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6615f9d969e9> in <module>()
# ----> 1 x+b
#
# NameError: name 'b' is not defined

# %%
# you can use varible as a string also
c='Canada is a great country'
print c
type(c) # here it show the type of string
# Out:
# Canada is a great country
# str

# %%
x+c # you can't add string with the number
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-5026474bcf73> in <module>()
# ----> 1 x+c
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
c+ 'Thunder bay is in Ontario' # you can add string with the string this is called concatenation
# Out:
# 'Canada is a great countryThunder bay is in Ontario'

# %% [markdown]
# Not only a pvariable value change during it use with in program; the type of variable also change as well.

# %%
len(c)
# Out:
# 25

# %% [markdown]
# ##### String slicing

# %%
c[0] # it will print the first alphabet of variable c
# Out:
# 'C'

# %%
c[0:6] # it will print the alphabet from o to 6; total 7 alphabet
# Out:
# 'Canada'

# %%
c[-3] #
# Out:
# 't'

# %%
s=100 #saving
f=1.1 #factor
#now assign product of saving and factor to value1
value1=f*s
#now print the type of value1
print(type(value1))
# Out:
# <type 'float'>

# %% [markdown]
# If we want to know the lenth of our string we can use length.

# %%
a=12
print('Our new variable value',a,'and type',type(a))
a='xyz'
print('Our new variable value',a,'and type',type(a))
# Out:
# ('Our new variable value', 12, 'and type', <type 'int'>)
# ('Our new variable value', 'xyz', 'and type', <type 'str'>)

# %% [markdown]
# Most variables maintain their original type throughout a program’s execution. A variable should have a specific meaning within a program, and its meaning should not change during the program’s execution. While it is not always the case, sometimes when a variable’s type changes its meaning changes as well.

# %%
street_line = 156
bus_number=45
print("street_line =", street_line)
print("bus_number =", bus_number)
# Out:
# ('street_line =', 156)
# ('bus_number =', 45)

# %% [markdown]
# #### User Input:-
#
# The print function shows the programer the textual information. Sometimes program may be used to print funtion to get information from the user. The simplest use of the input function assigns a string to a variable:
#
# x = input()
#
# The parentheses are empty because, the input function does not require any information to do its job.

# %%
print('Please enter the interger you want to print:')
x = input()
print('\n') #this command give space between two print line
print('Please enter another integer value:')
y = input()
x1 = int(x)
x2 = int(y)
print(x1, '+', x2, '=', x1 + 22)
# Out:
# Please enter the interger you want to print:
# 76
#
#
# Please enter another integer value:
# 76
# (76, '+', 76, '=', 98)

# %% [markdown]
# Here line 2 and 5 require the user input.The program shop after printing the first line and start again after geeting the user input.After the program prints the second message it again pauses to accept the user’s second entry.
# Since user input almost always requires a message to the user about the expected input, the input function optionally accepts a string that it prints just before the program stops to wait for the user to respond.

# %% [markdown]
# ## 8 Lists
# Lists are very similar to arrays. They can contain any type of variable, and they can contain as many variables as you wish. Lists can also be iterated over in a very simple manner. Here is an example of how to build a list.

# %% [markdown]
# In python you can use help(....) to know about any word or command.

# %%
help(list).
# Out:
# Help on class list in module __builtin__:
#
# class list(object)
#  |  list() -> new empty list
#  |  list(iterable) -> new list initialized from iterable's items
#  |
#  |  Methods defined here:
#  |
#  |  __add__(...)
#  |      x.__add__(y) <==> x+y
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x
#  |
#  |  __delitem__(...)
#  |      x.__delitem__(y) <==> del x[y]
#  |
#  |  __delslice__(...)
#  |      x.__delslice__(i, j) <==> del x[i:j]
#  |
#  |      Use of negative indices is not supported.
#  |
#  |  __eq__(...)
#  |      x.__eq__(y) <==> x==y
#  |
#  |  __ge__(...)
#  |      x.__ge__(y) <==> x>=y
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __getslice__(...)
#  |      x.__getslice__(i, j) <==> x[i:j]
#  |
#  |      Use of negative indices is not supported.
#  |
#  |  __gt__(...)
#  |      x.__gt__(y) <==> x>y
#  |
#  |  __iadd__(...)
# ...

# %%
a = [0, 1, 2, 3, 12, 20, 8, 30]
####[0,1,2,3,4,5,6,7] It shows the postion of number in variable a
b=[55,87,76,0,'lakehead', 'Thunder Bay']

# %% [markdown]
# You can find out the length of the array using len()

# %%
len(b) # it gives us the length of variable b
# Out:
# 6

# %%
len(a) # it gives us the length of variable a
# Out:
# 8

# %%
b[0] # it will give the digit at position zero
# Out:
# 55

# %%
b[1] #it gives us the digit at number 1
# Out:
# 87

# %%
b[2]# it gives us the digit at number 2
# Out:
# 76

# %%
b[5] # it gives us the digit at number 5
# Out:
# 'Thunder Bay'

# %%
b[2:5] # Print the number or string from  position 2 to 5
# Out:
# [76, 0, 'lakehead']

# %% [markdown]
# The first element of b is b[0], the second is b[1], the third is b[2], and so on. Some computer languages index lists starting with 0, like Python and C, while others index lists (or things more-or-less equivalent) starting with 1. It’s important to keep in mind that Python uses the former convention: lists are zero-indexed.

# %% [markdown]
# The last element of this array is b[4], because b has 5 elements. The last element can also be accessed as b[-1], no matter how many elements b has, and the next-to-last element of the list is b[-2], etc.

# %%
b[4] # it gives us the digit at number 4
# Out:
# 'lakehead'

# %%
b[-1] # it gives us the digit at number -1
# Out:
# 'Thunder Bay'

# %% [markdown]
# NOTE THAT negative indics startt from the end with 1.

# %%
a[-3] # print the number from -3 or 6
# Out:
# 20

# %% [markdown]
# If you want to change any number you can change it at any time.Indivitual element of a lists can be changed at any time.

# %%
b
# Out:
# [55, 87, 76, 0, 'lakehead', 'Thunder Bay']

# %%
b[2]=b[2]+120
b[3]=5.7

# %%
b
# Out:
# [55, 87, 436, 5.7, 'lakehead', 'Thunder Bay']

# %% [markdown]
# You can also add lists, but the result might surprise you:

# %%
a+a
# Out:
# [0, 1, 2, 3, 12, 20, 8, 30, 0, 1, 2, 3, 12, 20, 8, 30]

# %%
a+b
# Out:
# [0, 1, 2, 3, 12, 20, 8, 30, 55, 87, 436, 5.7, 'lakehead', 'Thunder Bay']

# %% [markdown]
# Here we see that 2 was added to the previous value of b[0] and the value at '0' was replaced by the floating point number 5.7.

# %% [markdown]
# you can access to the piece of list using slicing. That means you can divided your list into many pieces

# %% [markdown]
# you can access the slicing by spacing the ':'. This one of the powerful features we have in list. There are some example of the list.

# %%
b[4:] # it will give us all the number or string after postion 4
# Out:
# ['lakehead', 'Thunder Bay']

# %%
b[:5] # it will give us all the number or string before postion 5
# Out:
# [55, 87, 436, 5.7, 'lakehead']

# %%
b[:]
# Out:
# [55, 87, 436, 5.7, 'lakehead', 'Thunder Bay']

# %% [markdown]
# But you can really not tell which area correspound to which part of your house.

# %% [markdown]
# ### Slicing Lists

# %% [markdown]
# ##### Lists of List
# A list contain any python type. But a list  itself is also a python type. That means a list can also contain a list

# %%
b[2:5] # Print the number or string from  postion 2 to 5
# Out:
# [436, 5.7, 'lakehead']

# %% [markdown]
# ##### Subnetting List
#
# value=['a',1.98,'b',2.0,'c',1.24,'d',2.45]
#
# So now number of list is [0,1,2,3,4,5,6,7]
#
# you can use the list of [-8,-7,-6,-5,-4,-3,-2,-1]

# %%
value=['a',1.98,'b',2.0,'c',1.24,'d',2.45]
######[0,1,2,3,4,5,6,7]
######[-8,-7,-6,-5,-4,-3,-2,-1]
print(len(value)) # using this command we can calculate length of our value
# Out:
# 8

# %%
# You can access a specific entry in a list, the entries start at 0.
value[0]
# Out:
# 'a'

# %%
value[2]
# Out:
# 'b'

# %%
value[:6] # print the value from 0 to 5
# Out:
# ['a', 1.98, 'b', 2.0, 'c', 1.24]

# %%
value[2:7] # it will print all the value from 2 to 7
# Out:
# ['b', 2.0, 'c', 1.24, 'd']

# %%
# you can also use negative indices, where -1 is the last entry
value[-2]
# Out:
# 'd'

# %%
value*2 # you can "multiply" lists, this appends (repeats) the same list to itself 3 times (or whatever you multiply by).
# Out:
# ['a',
#  1.98,
#  'b',
#  2.0,
#  'c',
#  1.24,
#  'd',
#  2.45,
#  'a',
#  1.98,
#  'b',
#  2.0,
#  'c',
#  1.24,
#  'd',
#  2.45]

# %%
# Lists can also include mixed data types, including other lists... what you put in a list is arbitrary
value1 = [10, 17, 'our list', value,  -1]
print value1
# Out:
# [10, 17, 'our list', ['a', 1.98, 'b', 2.0, 'c', 1.24, 'd', 2.45], -1]

# %% [markdown]
# ##### Tuples:-

# %% [markdown]
# A tuples is an immutable list. you can't change it.
#
# 1.A tuples is defined in the same way as a list. But whole tuples are enclosed in parentheses instead of square brackets.
#
# 2.Slicing works here also just like in list.When you slice a list you will get a list so in the same way you can slice tuples also.
#
# 3.The elements of a tuple have a defined order, just like a list.
#
# 4.Negative indices count from the end.

# %%
x = (1, 2, 6, 9, 9, 10, 13)

# %%
x[2]
# Out:
# 6

# %%
x[2]=3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-193-b9b7674a6d63> in <module>()
# ----> 1 x[2]=3
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# When we tried to change x[2], the system returned an error because we are not allowed to do  changing of an element of a tuple. Tuples offer some degree of safety when we want to define lists of immutable constants.
# An immutable object cannot be changed. Once created, it always has the same values.

# %% [markdown]
# ##### Dictionaries:-
#
# A dictionary is also collection of Python objects,same as list, but one that is indexed by strings, tuples:for example i have sub-branch  of electrical department and student count in each sub-branch.

# %%
sb = {"computer":243, "electronic":354, "Digital":765,"Biomedical":456,"Signal":354,"power":754}

# %% [markdown]
# The dictionary above has six parts and each one is separated by commas, each entry has a key, which in this case is a string, and a value, which in this case is number of students in a department sub-branch. Each key and its values are separated by a colon.

# %%
sb["Digital"]
# Out:
# 765

# %% [markdown]
# A key can be anything. It can be a string, number and even tuples also. but a key can't be a list.

# %%
sb["Biomedical"]
# Out:
# 456

# %% [markdown]
# The best part about the dictionaries is you can build and add.

# %%
a={}

# %%
a["Country"] = "Canada"

# %%
a["Province"] = "Ontario"

# %%
a["City"] = "Thunder Bay"

# %%
a # here we have our Dictionaries that we just created.
# Out:
# {'City': 'Thunder Bay', 'Country': 'Canada', 'Province': 'Ontario'}

# %% [markdown]
# The best part of Dictionaries is that you can seperate your key and value and print them.You can just print them writing .keys() or .values()

# %%
a.keys()
# Out:
# ['Province', 'Country', 'City']

# %%
a.values()
# Out:
# ['Ontario', 'Canada', 'Thunder Bay']

# %%
a=1
b=2
c=3
d=4
e=5
area=[a,b,c,d,e]
print(area)
# Out:
# [1, 2, 3, 4, 5]

# %%
hall=1
kit=2
liv=3
bed=4
bath=6

# now i just used the short form of all the words; now you can change them into full words using this method

areas=['Hallway',hall,'Kitchen',kit,'Bedroom',bed,'living room',liv,'Bathroom',bath]
print(areas)
# Out:
# ['Hallway', 1, 'Kitchen', 2, 'Bedroom', 4, 'living room', 3, 'Bathroom', 6]

# %%
# area variable( in square meter)
hall=10.75
kit=19.45
liv=20.0
bed=7.25
bath=9.50
# So Now house lists of list
housearea=[["Hallway",hall],["kitchen",kit],["living room",liv],["Bedroom",bed],["Bathroom",bath]]
# Now print HOUSEAREA
print(housearea)
#now print type of housearea
print(type(housearea))
# Out:
# [['Hallway', 10.75], ['kitchen', 19.45], ['living room', 20.0], ['Bedroom', 7.25], ['Bathroom', 9.5]]
# <type 'list'>

# %% [markdown]
# ##### Creating and modifying lists:-

# %% [markdown]
# Python has functions for creating and augmenting lists. The most useful is the range function, which can be used to create a uniformly spaced sequence of integers. The general form of the function is $ range ([start,] stop[, step]) $, where the arguments are all integers; those in square brackets are optional.

# %%
range(8)    # makes a list of 8 integers from 0 to 7
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
range(2,6) # makes a list of 8 integers from 2 to 6
# Out:
# [2, 3, 4, 5]

# %%
range(1,8,2) # makes a list of 8 integers from 1 to 8 with a increment of 2
# Out:
# [1, 3, 5, 7]

# %% [markdown]
# ## 9. NumPy Array:-
#
# The NumPy array usually called ndarray in NumPy documentation.Same as a list array is used in python to store the data. Same as list array can also store any type of data.The best example to defferentiate between list and array is if you divide an array by 2 then every element in the list will be divided by 2.But if you try to divide a list, python will give you an error. That's why array is very useful, if you are going to use mathmatical form in python.
#
# ** you have a list you want to convert it into a 1-D array.

# %%
x=[2,5,7,23,4,6,32,5,2.3,5]
y=array(x)

# %%
y
# Out:
# array([  2. ,   5. ,   7. ,  23. ,   4. ,   6. ,  32. ,   5. ,   2.3,   5. ])

# %% [markdown]
# Lets try to divide the array with some number and see what happens.

# %%
x = array([12, 15, 15, 18])
x/3 # array is divided by 3
# Out:
# array([4, 5, 5, 6])

# %% [markdown]
# Now, lets do the same stuff with list. List will give us error.

# %%
x = (12, 15, 15, 18)
x/3 # array is divided by 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-202-03d3c307c8ec> in <module>()
#       1 x = (12, 15, 15, 18)
# ----> 2 x/3 # array is divided by 3
#
# TypeError: unsupported operand type(s) for /: 'tuple' and 'int'

# %% [markdown]
# our program is exactly same like the last program. but it did not run. It will give us error.It take some extra effort to use the array, but they have to be declared while list don't. Bacause they are part of python syntax.

# %% [markdown]
# You can use linspace to genrate array. The linspace function creates an array of N evenly spaced points between a start point and end point.The form of the function is linspace(start, stop, N).

# %%
linspace(0,20,12)
# Out:
# array([  0.        ,   1.81818182,   3.63636364,   5.45454545,
#          7.27272727,   9.09090909,  10.90909091,  12.72727273,
#         14.54545455,  16.36363636,  18.18181818,  20.        ])

# %%
linspace(0,10,4)
# Out:
# array([  0.        ,   3.33333333,   6.66666667,  10.        ])

# %% [markdown]
# you can do addition, subtraction, multiplication, and division by each other, provided the arrays are of same size.

# %%
x=array([5,10,4])

y=array([23,45,10])

x+y
# Out:
# array([28, 55, 14])

# %%
x-y
# Out:
# array([-18, -35,  -6])

# %%
x*y
# Out:
# array([115, 450,  40])

# %%
y/x
# Out:
# array([4, 4, 2])

# %% [markdown]
# Array can be sliced same as string and list.Slicing the array is done in the same way as we did with list and string.

# %%
x=array([5,10,4,14,54,6,5,43,4])

# %%
x[:4] # gives us the first four number from array x
# Out:
# array([ 5, 10,  4, 14])

# %%
x[4:] #gives us all the numbers after 4
# Out:
# array([54,  6,  5, 43,  4])

# %%
x[5:8] # gives us  the number between 5 and 8
# Out:
# array([ 6,  5, 43])

# %%
x[:-1]
# Out:
# array([ 5, 10,  4, 14, 54,  6,  5, 43])

# %% [markdown]
# Element to element the difference of two array will be done like this

# %%
x[1:]-x[:-1]
# Out:
# array([  5,  -6,  10,  40, -48,  -1,  38, -39])

# %% [markdown]
# ## 10 Function:-
#
# Sometimes a code is mainly organized in function.Function lets you use some parts of your code without copy pasting it again.There are some built-in functions but still you can create your own functions. You can define functions to provide the required functionality.

# %%
def square(num):
    return num ** 2

# %%
square(5)
# Out:
# 25

# %%
# multiple return values
def powers(n):
    return n ** 2, n ** 3, n ** 4

# %%
powers(2)
# Out:
# (4, 32, 1024)

# %%
def func(number):
   
    "print 'number' and findout number of characters "
    
    print(number + " has " + str(len(number)) + " characters")

# %%
help(func)
# Out:
# Help on function func in module __main__:
#
# func(number)
#     print 'number' and findout number of characters

# %%
func("number")
# Out:
# number has 6 characters

# %% [markdown]
# ## 11 Plotting
#
# Numpy:- This is the module which does most of the array and mathematical manipulation.
#
# Matplotib:- This is the module you will be using for plotting.
#
# Ploting is part of visualization of any data in quick and east way when you are not familiar with your data.

# %% [markdown]
# Graphical representation of data in python is one of the most important features, it helps us to understand the data.
# Plotting is not a core part of python but we can plot through several library modules. The most highly developed and widely used plotting package for Python is MatPlotLib (http://MatPlotLib.sourceforge.net/). It is a powerful and flexible program for 2-d plotting with Python.
#
# Because MatplotLib is external library, but it is a collection of libraries.Whenever you need it you just import it and then use it.Therefore, for any program for which you would like to produce 2-d plots, you should include the lines.
#
# Again we'll use inline plotting, though it can be useful to skip the "inline" backend to allow interactive manipulation of the plots.

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# $pyplot$ plot library provides everthing that you need to plot for 2-d plotting.The standard prefix for it is plt. The two statements above must appear before any calls to NumPy or MatPlotLib routines are made. MatPlotLib is automatically loaded with the IPython shell so you do not need to use import matplotlib.pyplot nor do you need to use the plt prefix when working in the IPython shell.

# %% [markdown]
# ##### Basic plotting

# %% [markdown]
# we begin with plotting a basic plot that shows us some very basic structure of the MatplotLib. Just type the plot command and give some number and execute the command.

# %%
plot([10,20,30,20,50,50,60,60,70])

# %% [markdown]
# A window should appear with a plot that looks something like this.The $plot$ function represents a line between the data points that were entered.Now, we will take a look at the plot and it uses two variable:

# %%
plot(x,y)

# %%
# Make array of x value
x=[10,20,30,40,50]
# make array of y value
y=[15,20,45,65,75]
# use pylab to plot value of x and y
plt.plot(x,y)

# %% [markdown]
# This plot is called line plot

# %% [markdown]
# #### Adding Titles and Labels
# Now our plt is working properly, now we can start adding information to our plot.We can add titles for our plot and for our axis also.

# %%
# Make array of x value
x=[10,20,30,40,50]
# make array of y value
y=[15,20,45,65,75]
# use pylab to plot value of x and y
plt.plot(x,y)
plt.title('This plot shows the relationship between x and y')

# %% [markdown]
# Next, add label to our x and y axis

# %%
#add x and y labels
plt.xlabel('x-axis')
plt.ylabel('y-label')

# %% [markdown]
# So, you can see this plotting with labels on the axis.

# %%
# Make array of x value
x=[10,20,30,40,50]
# make array of y value
y=[15,20,45,65,75]
# use pylab to plot value of x and y
plt.plot(x,y)
# Add title
plt.title('This plot shows the relationship between x and y')
# add x and y labels
plt.xlabel('x-axis')
plt.ylabel('y-axis')
#show the plot on the screen
plt.show()

# %% [raw]
# When we run this program, we now have a plot that is more informative.

# %% [markdown]
# ##### Customizing Plot
#
# matplotlib includes many customization features, such as different colors, point symbols, and sizing. Depending on our needs, we may want to play around with different scales, using different ranges for our axis. We can plot more than one plot on same axis. You just need to define the x and y arrays for each of your plot.

# %% [markdown]
# ##### Change Line Colour in Line plot and Scatter plot marker style:-
#
# You can change your line plot style e.g. to be dotted,dashed etc.
#
# Example:- plot(x,y,'..") This will give us dotted line. For more styles you can search in help(matplotlib.pyplot.plot)
#
# Options for line styles are
#  '-' = solid
#
# '--' = dashed
#
# ':' = dotted
#
# '-.' = dot-dashed
#
#  '.' = points
#
# 'o' = filled circles
#
#  '^' = filled triangles
#
#  Other options for the color characters are:
#  'r' = red
#
# 'g' = green
#
#  'b' = blue
#
#  'c' = cyan
#
#  'm' = magenta
#
#  'y' = yellow
#
#  'k' = black
#
#  'w' = white
#
# $Changing Marker style$:-
#
# Lastly, you can also vary the marker style you use. Try:
#
# plot(x,y, marker=’b*’)
#
# This should give you blue star-shaped markers.

# %%
# Make array of x value
x=[10,20,30,40,50]
# make array of y value
y=[15,20,45,65,75]
# use pylab to plot value of x and y
plt.plot(x,y,'--') # shape is '--'
#we can arrange axis limit.
plt.xlim(0,80)
plt.ylim(0,80)
# Add title
plt.title('This plot shows the relationship between x and y')
# add x and y labels
plt.xlabel('x-axis')
plt.ylabel('y-axis')
#show the plot on the screen
plt.show()

# %%
import matplotlib.pyplot as plt
# Make array of x value
x=[10,20,30,40,50]
p=[20,34,67,78,98]

# make array of y value
y=[15,20,45,65,75]
q=[30,40,60,70,90]
# use pylab to plot value of x and y
plt.plot(x,y,'--') # Colour of our line and shape 
plt.plot(p,q,'r')
# Add title
plt.title('This plot shows the relationship between x and y')
#we can arrange axis limit.
plt.xlim(0,80)
plt.ylim(0,80)
# add x and y labels
plt.xlabel('x-axis')
plt.ylabel('y-axis')
#show the plot on the screen
plt.show()

# %% [markdown]
# ##### Scatter plot:-

# %%
# Make array of x value
x=[10,20,30,40,50]
# make array of y value
y=[15,20,45,65,75]
# use pylab to plot value of x and y
plt.scatter(x,y,marker='^') # change the shape of marker
#we can arrange axis limit.
plt.xlim(0,80)
plt.ylim(0,80)
# Add title
plt.title('This plot shows the relationship between x and y')
# add x and y labels
plt.xlabel('x-axis')
plt.ylabel('y-axis')
#show the plot on the screen
plt.show()

# %%
# Make array of x value
x=[10,20,30,40,50]
# make array of y value
y=[15,20,45,65,75]
# use pylab to plot value of x and y
plt.scatter(x,y,c='r')
#we can arrange axis limit.
plt.xlim(0,80)
plt.ylim(0,80)
# Add title
plt.title('This plot shows the relationship between x and y')
# add x and y labels
plt.xlabel('x-axis')
plt.ylabel('y-axis')
#show the plot on the screen
plt.show()

# %% [markdown]
# Now we plot 2 scatter value at single plot.

# %%
# Make array of x value
x=[10,20,30,40,50]
p=[20,34,67,78,98]
# make array of y value
y=[15,20,45,65,75]
q=[30,40,60,70,90]
# use pylab to plot value of x and y
plt.scatter(x,y,c='r') # Colour of our line is red now
plt.scatter(p,q,c='g')
# Add title
plt.title('This plot shows the relationship between x and y')
#we can arrange axis limit.
plt.xlim(0,80)
plt.ylim(0,80)
# add x and y labels
plt.xlabel('x-axis')
plt.ylabel('y-axis')
#show the plot on the screen
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
n=50
x=np.random.normal(5,5,n)
y=np.random.normal(5,5,n)
plt.scatter(x,y)
plt.show()

# %% [markdown]
# If you want to add more data into your actual value of x and y.

# %%
# let us try another type of plot like sine and cosine plot
import pylab as plt
import numpy as np
#lets plot some sinusoild
x = np.linspace(0, 20, 1000)  # 100 evenly-spaced values from 0 to 50
y = np.sin(x)

plot(x, y,'y') # As showed, you can change your line colour

# %%
x = np.linspace(0, 20, 1000)  # 100 evenly-spaced values from 0 to 50
y = np.cos(x)
plt.title('Cosine function plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plot(x, y, '--' )

# %%
y = np.sin(2 * np.pi * x)
pylab.plot(x, y,'r') # change the colour of our plot
pylab.title(r'$\sin(2 \pi x)$')  # the `r` before the string indicates a "raw string"
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plot(x,y,'.') # here i changed my line graph shape with point

# %% [markdown]
# ##### Cusomizing the Plot: Legends
#
# Multiple lines can be shown on the same plot. In this case, you can use a legend to label the two lines:

# %%
x = np.linspace(0, 20, 1000)  # 100 evenly-spaced values from 0 to 50
y = np.cos(x)
y2=np.sin(x)
plt.title('Cosine and sine function plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plot(x, y,'r',label='cosine')
plot(x, y2,'y',label='sine')
legend(loc='upper right')

# %%
x = np.linspace(0, 20, 500)  # 100 evenly-spaced values from 0 to 50
y = np.cos(x)
y2=np.sin(x)
plt.title('Cosine and sine function plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plot(x, y,'bo',label='cosine')
plot(x, y2,'--',label='sine')
legend(loc='upper right')

# %%
fig = plt.figure()  # a new figure window
pt= fig.add_subplot(1, 1, 1)  # specify (nrows, ncols, axnum)

# %%
import numpy as np
p = np.linspace(0, 20, 500)
q = np.sin(p)

pt.plot(p, q)
display(fig)  # this is required to re-display the figure

# %%
q2 = np.cos(p)
pt.plot(p, q2)

fig  # this works similarly to display(fig)

# %%
pt.set_ylim(-1.5, 2.0)
fig

# %%
pt.legend(['sine', 'cosine'])
fig

# %% [markdown]
# ##### Multi plot:-
# Using this plot we can plot multiple plot .

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.subplot(2,2,1)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
plt.show()

# %% [markdown]
# ##### Pie Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

depart = 'computer', 'electrical', 'civil', 'MBA'
number = [34, 23, 57, 67]
plt.pie(number, labels=depart)
plt.show()

# %%
# Using these method you can add more features into your pie
depart = 'computer', 'electrical', 'civil', 'MBA'
number = [34, 23, 57, 67]
col= ['red', 'green', 'violet', 'lightblue']
explode = (0, 0, 0.2, 0)  # explode 3rd slice, Change the number and see what happen??
 
#now, let's do some plotting
plt.pie(number, explode=explode, labels=depart, colors=col,autopct='%1.1f%%', shadow=True, startangle=200)
#if you want your pie at right position, you can use this command.
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### Quiver Plots

# %%
import numpy as np
import matplotlib.pyplot as plt

x,y = np.mgrid[0:10,0:10] # 10 will show us 10 arrow in one line till 10 points on x and y axis
plt.quiver(x,y)
plt.show()

# %% [markdown]
# ##### Histogram:-
# Matplotlib can be used to create histograms. A histogram shows the frequency on the vertical axis and the horizontal axis is another dimension. Usually it has bins, where every bin has a minimum and maximum value. Each bin also has a frequency between x and infinite.

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
 
a = [12,15,17,20,4,7,9,22,62,4,34]
bins = 5
histogram = plt.hist(a, bins, facecolor='blue', alpha=0.5)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Histogram')
plt.show()

# %% [markdown]
# you can add many things in your histogram and you can do such as a fit line, labels and so on.

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
 
#
m = 50 # mean of distribution
sd = 5 # standard deviation of distribution
x = m + sd * np.random.randn(500)
bins = 15
# the histogram of the data
patches = plt.hist(x, bins, normed=2, facecolor='green', alpha=0.2)
y = mlab.normpdf(bins, m, sd)# now,add lines
#plotting 
plt.plot(bins, y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Histogram of IQ: $\mu=50$, $\sigma=5$')

# %% [markdown]
# ##### Bar graph:-
# Using the matplotlib we can plot the bar also.

# %%
import matplotlib.pyplot as plt;
import numpy as np
import matplotlib.pyplot as plt
 
depart = ('Civil', 'Computer', 'Electrical', 'History', 'Nursing', 'MBA')
number = [100,145,130,125,120,111]
pos = np.arange(len(depart))
plt.bar(pos, number, align='center', alpha=0.8) #Change the alpha and see what happen???
plt.xticks(pos, depart)
plt.ylabel('Count')
plt.title('Number of people in each department')
plt.show()

# %% [markdown]
# The best part about the bar graph is that you can plot them using horizonal by using $barh()$. When you are going to plot horizontal plot, you need to change the x and y axis name.

# %%
import matplotlib.pyplot as plt; 
import numpy as np
import matplotlib.pyplot as plt
 
depart = ('Civil', 'Computer', 'Electrical', 'History', 'Nursing', 'MBA')
number = [100,145,130,125,120,111]
pos = np.arange(len(depart))
# i changed the bar into barh() to get horizontal plot.
plt.barh(pos, number, align='center', alpha=0.8) #Change the alpha and see what happen???
plt.yticks(pos, depart)
plt.xlabel('Count')
plt.title('Number of people in each department')
plt.show()

# %% [markdown]
# ##### Grid:-

# %%
import numpy as np
import matplotlib.pyplot as plt

axes = gca()
axes.set_xlim(0,4)
axes.set_ylim(0,3)
axes.set_xticklabels([])
axes.set_yticklabels([])

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.subplot(2,2,1)
plt.subplot(2,2,3)
plt.subplot(2,2,4)

plt.show()

# %% [markdown]
# #### 3D plotting:-

# %% [markdown]
# Just like before when we created a 2D axis and called several plotting methods on it, here we'll create some 3D axis objects and call 3D plotting routines. Below are several examples.we need these two lines always. These two lines helps us to get a 3D Plot.
#
# $1.fig=plt.figure()$
#
# $2.ax=plt.axes(projection=′3d′)$

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot(x, y)

# %%
import numpy as np
import matplotlib.pyplot as plt
#access 3-d plot you need to install this module
from mpl_toolkits.mplot3d import Axes3D

fig=plt.figure() # Fig and ax help you to get the 3-d plot
ax=Axes3D(fig) # # these two commands are most important factor in 3-d plot
x=np.arange(-2, 4, 0.25) #x-axis and their arrange (x,y,z)
y=np.arange(-2, 4, 0.25) #y-axis
x,y=np.meshgrid(x, y) 
a=np.sqrt(x**2 + y**2)
b=np.cos(a)
ax.plot_surface(x, y, b)
plt.show()

# %%
# this 3d plot shows us how to draw a hot shape plot
fig=plt.figure() # Fig and ax help you to get the 3-d plot
ax=Axes3D(fig)
x=np.arange(-2, 4, 0.25) #x-axis and their arrange (x,y,z)
y=np.arange(-2, 4, 0.25) #y-axis
x,y=np.meshgrid(x, y) 
a=np.sqrt(x**2 + y**2)
b=np.cos(a) 
ax.plot_surface(x, y, b,cmap='hot') # you can change or remove cmap.
plt.show()

# %% [markdown]
# ###### 3-D Scatter Plot:-
# 3d scatter plot takes all the keyword parameter like 2d scatter plot. To create a 3d scatter plot we need to pass the "projection=3d".

# %%
# Again we need to use those 2 important lines for 3D.
fig=plt.figure()
ax=plt.axes(projection='3d')
#this projection only contains the sine function
z=np.linspace(0, 4, 300)
x=z*np.sin(5 * z) #x-axis
ax.scatter(x,z)

# %%
# Again we need to use those 2 important lines for 3d.
fig=plt.figure()
ax=plt.axes(projection='3d')
#this projection now contains both consine and sine funtions
z=np.linspace(0, 4, 300)
x=z*np.sin(5*z) # you can play with value 5 and see the difference in your plot.
y=z*np.cos(5*z)
ax.scatter(x,y,z)

# %%
# Again we need to use those 2 important lines for 3d.
fig=plt.figure()
ax=plt.axes(projection='3d')
#this projection now contains both consine and sine funtion
z=np.linspace(0, 4, 300)
x=z*np.sin(80 * z) # you can play with value 5 and see the difference in your plot.
y=z*np.cos(80 * z)
ax.scatter(x,y,z)

# %% [markdown]
# ## 12. Reding the input:-

# %% [markdown]
# Sometimes you need to read some files to analyze them. So you need to know how to do it.
# For e.g:-

# %%
# %matplotlib inline
from skimage import novice, data, io, exposure
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

#the simplest way to open and display an image uses the novice module from skimage
brainpic = novice.open('braincomplete.png')
brainpic.show()

# %% [markdown]
# Now i will show how to open a excel file. Which is in .CSV format.

# %%
# %matplotlib inline
#Import basic packages
import numpy as np 
import pandas as pd
import matplotlib as matplot
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mydataset = pd.read_csv('HR_comma_sep.csv')

# %%
# Using this command you can find out the shape of your .csv file.
mydataset.shape
# Out:
# (14999, 10)

# %% [markdown]
# So we have 14999 rows and 10 coloums.
# Now, we can find out the features of our files and see what kind of value we have here.

# %%
mydataset.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
# using this command you can findout the mean, Standard deviation, minimum and maximum value
mydataset.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
#if you want to know the format of your data inside a file
mydataset.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# sales                     object
# salary                    object
# dtype: object

# %%
mydataset.mean()
# Out:
# satisfaction_level         0.612834
# last_evaluation            0.716102
# number_project             3.803054
# average_montly_hours     201.050337
# time_spend_company         3.498233
# Work_accident              0.144610
# left                       0.238083
# promotion_last_5years      0.021268
# dtype: float64

# %% [markdown]
# let us know about one feature.So we have one feature sales and it has many department information in it.

# %%
mydataset.groupby(["sales"]).mean()
# Out:
#              satisfaction_level  last_evaluation  number_project  \
# sales
# IT                     0.618142         0.716830        3.816626
# RandD                  0.619822         0.712122        3.853875
# accounting             0.582151         0.717718        3.825293
# hr                     0.598809         0.708850        3.654939
# management             0.621349         0.724000        3.860317
# marketing              0.618601         0.715886        3.687646
# product_mng            0.619634         0.714756        3.807095
# sales                  0.614447         0.709717        3.776329
# support                0.618300         0.723109        3.803948
# technical              0.607897         0.721099        3.877941
#
#              average_montly_hours  time_spend_company  Work_accident  \
# sales
# IT                     202.215974            3.468623       0.133659
# RandD                  200.800508            3.367217       0.170267
# ...

# %% [markdown]
# Using python you can compare your two features, Say you want to compare salary of each department. How many employee are getting high, medium or low salary.

# %%
sns.factorplot("sales", col="salary", col_wrap=3, data=mydataset, kind="count", size=15, aspect=.4)

# %%
#Lets plot the histogram of each feature.
mydataset.hist(figsize =(15,15))
plt.show()

# %%
# You can even compare two features also
sns.barplot(x = 'time_spend_company', y = 'satisfaction_level', data = mydataset)
sns.plt.title('Satisfaction based on the time spend at company')

# %%
sns.countplot(x="time_spend_company",hue='salary', data=mydataset)
plt.title('Salary based on the time spend in company')

# %% [markdown]
# ## 13 References:-
#
#     1.http://jupyter.readthedocs.org/en/latest/
#
#     2.http://jupyter-notebook.readthedocs.org/en/latest/notebook.html
#
#     3.http://matplotlib.org
#
#     4.https://media.readthedocs.org/pdf/jupyter/latest/jupyter.pdf
#
#     5.http://do1.dr-chuck.com/pythonlearn/EN_us/pythonlearn.pdf
#
#     6.http://www.greenteapress.com/thinkpython/thinkpython.pdf
